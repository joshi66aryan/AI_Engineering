# %% [markdown]
# ## Data Loading

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = {"Name":["python", "java", "C#", 'c++'], "Marks": [98,97,95,94]}
df = pd.DataFrame(data)
df
# Out:
#      Name  Marks
# 0  python     98
# 1    java     97
# 2      C#     95
# 3     c++     94

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/train.csv")

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 483          484         1       3      Turkula, Mrs. (Hedwig)  female  63.0
# 19            20         1       3     Masselmani, Mrs. Fatima  female   NaN
# 491          492         0       3         Windelov, Mr. Einar    male  21.0
# 159          160         0       3  Sage, Master. Thomas Henry    male   NaN
# 397          398         0       2     McKane, Mr. Peter David    male  46.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 483      0      0              4134   9.5875   NaN        S
# 19       0      0              2649   7.2250   NaN        C
# 491      0      0  SOTON/OQ 3101317   7.2500   NaN        S
# 159      8      2          CA. 2343  69.5500   NaN        S
# 397      0      0             28403  26.0000   NaN        S

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[['Age','Cabin','Embarked']]
# Out:
#       Age Cabin Embarked
# 0    22.0   NaN        S
# 1    38.0   C85        C
# 2    26.0   NaN        S
# 3    35.0  C123        S
# 4    35.0   NaN        S
# ..    ...   ...      ...
# 886  27.0   NaN        S
# 887  19.0   B42        S
# 888   NaN   NaN        S
# 889  26.0  C148        C
# 890  32.0   NaN        Q
#
# [891 rows x 3 columns]

# %%
df.size
# Out:
# 10692

# %%
# returns the memory usage of each column and the index in bytes.
df.memory_usage(deep=False)
# Out:
# Index           132
# PassengerId    7128
# Survived       7128
# Pclass         7128
# Name           7128
# Sex            7128
# Age            7128
# SibSp          7128
# Parch          7128
# Ticket         7128
# Fare           7128
# Cabin          7128
# Embarked       7128
# dtype: int64

# %%
# returns the total memory usage of the entire DataFrame in bytes, including an accurate
# measure for object type columns (like strings).
df.memory_usage(deep=True).sum()
# Out:
# np.int64(292464)

# %%
# filling the na value for Age
df['Age'].fillna(df['Age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
# Create a separate df using integer-based positioning
# Selects rows 0-99 and columns 0-4 (PassengerId, Survived, Pclass, Name, Sex)
df_subset = df.iloc[0:100, 0:5]

# %%
df_subset.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female

# %%
# male survivor using loc
male_survivor = df.loc[(df['Sex'] == 'male') & (df['Survived'] == 1)]
male_survivor.head(2)
# Out:
#     PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 17           18         1       2  Williams, Mr. Charles Eugene  male   NaN
# 21           22         1       2         Beesley, Mr. Lawrence  male  34.0
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 17      0      0  244373  13.0   NaN        S
# 21      0      0  248698  13.0   D56        S

# %%
df_subset["PID_PCLASS"] = df_subset['PassengerId'] + df_subset['Pclass']
df_subset.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  PID_PCLASS
# 0                            Braund, Mr. Owen Harris    male           4
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           3

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# # Data Visualization

# %%
# Bar Graph - Survival count
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
# Pie Chart - Male vs Female passengers
df['Sex'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %%
# Histogram - Age distribution
df['Age'].hist(bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
# Scatter Plot - Age vs Fare
plt.scatter(df['Age'], df['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs Fare')
plt.show()
